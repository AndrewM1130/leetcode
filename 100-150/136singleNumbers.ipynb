# %%
## VSCode currently has bugs preventing the basic JP notebook image linking functionality
## i.e., ![pic name]('link') shows corrupted image
# %matplotlib inline
from IPython.display import Image
Image('img/complexity-cheatsheet.png')

# %% [markdown]
# Given a non-empty array of integers nums, every element appears twice except for one. Find that single one.
#
# You must implement a solution with a linear runtime complexity and use only constant extra space.
#
# **Example 1:**
#
# Input: nums = [2,2,1]\
# Output: 1
#
# **Example 2:**
#
# Input: nums = [4,1,2,1,2]\
# Output: 4
#
# **Example 3:**
#
# Input: nums = [1]\
# Output: 1
#
#
# **Constraints:**
#
# $1 \leq nums.length \leq 3 * 10^4$\
# $-3 * 10^4 \leq nums[i] \leq 3 * 10^4$
#
# Each element in the array appears twice except for one element which appears only once

# %%
class Solution:
    def singleNumber(self, nums) -> int:
        curr = 0
        for i in range(len(nums)):
            if nums.count(nums[i]) == 1:
                curr = nums[i]
        return curr

# %%
x = Solution()

# %%
nums = [2,2,1]
x.singleNumber(nums)
# Out:
# 1

# %%
nums = [4,1,2,1,2]
x.singleNumber(nums)
# Out:
# 4

# %%
nums = [1]
x.singleNumber(nums)
# Out:
# 1
